# %% [markdown]
# # **Customer Segmentation using Machine Learning Algorithms**

# %% [markdown]
# #### Overview
# 1. Import libraries
# 2. Load dataset
# 3. Explore & Clean the dataset
# 4. Data preprocessing
# 5. Train model
# 6. Save Model

# %% [markdown]
# -----

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Import Libraries</p>**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import seaborn as sns
from scipy.stats import norm
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import datetime
import math
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Load The Dataset</p>**

# %%
df = pd.read_excel('data/online_retail.xlsx')
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                    ...    ...          ...             ...
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom
#
# [525461 rows x 8 columns]

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Explore & Clean The Dataset</p>**

# %%
print(df.shape)
df.info()
df.describe(include='all')
# Out:
# (525461, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB
#          Invoice StockCode                         Description       Quantity  \
# count   525461.0    525461                              522533  525461.000000
# unique   28816.0      4632                                4681            NaN
# top     537434.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq       675.0      3516                                3549            NaN
# first        NaN       NaN                                 NaN            NaN
# last         NaN       NaN                                 NaN            NaN
# mean         NaN       NaN                                 NaN      10.337667
# std          NaN       NaN                                 NaN     107.424110
# min          NaN       NaN                                 NaN   -9600.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   19152.000000
#
#                 InvoiceDate          Price    Customer ID         Country
# count                525461  525461.000000  417534.000000          525461
# unique                25296            NaN            NaN              40
# top     2010-12-06 16:57:00            NaN            NaN  United Kingdom
# freq                    675            NaN            NaN          485852
# first   2009-12-01 07:45:00            NaN            NaN             NaN
# last    2010-12-09 20:01:00            NaN            NaN             NaN
# mean                    NaN       4.688834   15360.645478             NaN
# std                     NaN     146.126914    1680.811316             NaN
# min                     NaN  -53594.360000   12346.000000             NaN
# 25%                     NaN       1.250000   13983.000000             NaN
# 50%                     NaN       2.100000   15311.000000             NaN
# 75%                     NaN       4.210000   16799.000000             NaN
# max                     NaN   25111.090000   18287.000000             NaN

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df = df.fillna(method='backfill')
df.isna().sum().sum()
# Out:
# 0

# %%
# df['Customer ID'].fillna(pd.Series(range(1,107928),index=df['Customer ID'][df['Customer ID'].isna()==True].index))

# %%
df.duplicated().sum()
# Out:
# 6865

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df['Customer ID'] = df['Customer ID'].astype('int').astype('object') 
df['Customer ID'].dtype
# Out:
# dtype('O')

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          479047
# EIRE                      9660
# Germany                   8120
# France                    5754
# Netherlands               2768
# Spain                     1271
# Switzerland               1187
# Portugal                  1098
# Belgium                   1053
# Channel Islands            906
# Sweden                     901
# Italy                      729
# Australia                  654
# Cyprus                     546
# Austria                    537
# Greece                     517
# United Arab Emirates       432
# Denmark                    428
# Norway                     369
# Finland                    354
# Unspecified                310
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# RSA                        111
# Bahrain                    107
# Canada                      77
# Hong Kong                   76
# Thailand                    76
# Israel                      74
# Iceland                     71
# Korea                       63
# Brazil                      62
# West Indies                 54
# Bermuda                     34
# Nigeria                     32
# Lebanon                     13
# Name: Country, dtype: int64

# %%
plt.hist(df['Quantity'])
plt.show()

# %%
df = df[df['Quantity']>0]

# %%
plt.hist(df['Price'])
plt.show()

# %%
df = df[df['Price']>0]

# %%
df = df[['Customer ID', 'Country', 'Invoice', 'InvoiceDate', 'StockCode', 'Description', 'Quantity', 'Price']]
df
# Out:
#        Customer ID         Country Invoice         InvoiceDate StockCode  \
# 0            13085  United Kingdom  489434 2009-12-01 07:45:00     85048
# 1            13085  United Kingdom  489434 2009-12-01 07:45:00    79323P
# 2            13085  United Kingdom  489434 2009-12-01 07:45:00    79323W
# 3            13085  United Kingdom  489434 2009-12-01 07:45:00     22041
# 4            13085  United Kingdom  489434 2009-12-01 07:45:00     21232
# ...            ...             ...     ...                 ...       ...
# 525456       17530  United Kingdom  538171 2010-12-09 20:01:00     22271
# 525457       17530  United Kingdom  538171 2010-12-09 20:01:00     22750
# 525458       17530  United Kingdom  538171 2010-12-09 20:01:00     22751
# 525459       17530  United Kingdom  538171 2010-12-09 20:01:00     20970
# 525460       17530  United Kingdom  538171 2010-12-09 20:01:00     21931
#
#                                 Description  Quantity  Price
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12   6.95
# 1                        PINK CHERRY LIGHTS        12   6.75
# 2                       WHITE CHERRY LIGHTS        12   6.75
# 3              RECORD FRAME 7" SINGLE SIZE         48   2.10
# 4            STRAWBERRY CERAMIC TRINKET BOX        24   1.25
# ...                                     ...       ...    ...
# 525456                 FELTCRAFT DOLL ROSIE         2   2.95
# 525457         FELTCRAFT PRINCESS LOLA DOLL         1   3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL         1   3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG         2   3.75
# 525460               JUMBO STORAGE BAG SUKI         2   1.95
#
# [504731 rows x 8 columns]

# %%
df['Total Price'] = df['Quantity'] * df['Price']

# %%
df['InvoiceDate'] = df['InvoiceDate'].dt.date
df['Recency'] = (df['InvoiceDate'].max() + datetime.timedelta(days=1)) - df['InvoiceDate']
df['Recency'] = df['Recency']

# %%
df
# Out:
#        Customer ID         Country Invoice InvoiceDate StockCode  \
# 0            13085  United Kingdom  489434  2009-12-01     85048
# 1            13085  United Kingdom  489434  2009-12-01    79323P
# 2            13085  United Kingdom  489434  2009-12-01    79323W
# 3            13085  United Kingdom  489434  2009-12-01     22041
# 4            13085  United Kingdom  489434  2009-12-01     21232
# ...            ...             ...     ...         ...       ...
# 525456       17530  United Kingdom  538171  2010-12-09     22271
# 525457       17530  United Kingdom  538171  2010-12-09     22750
# 525458       17530  United Kingdom  538171  2010-12-09     22751
# 525459       17530  United Kingdom  538171  2010-12-09     20970
# 525460       17530  United Kingdom  538171  2010-12-09     21931
#
#                                 Description  Quantity  Price  Total Price  \
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12   6.95        83.40
# 1                        PINK CHERRY LIGHTS        12   6.75        81.00
# 2                       WHITE CHERRY LIGHTS        12   6.75        81.00
# 3              RECORD FRAME 7" SINGLE SIZE         48   2.10       100.80
# 4            STRAWBERRY CERAMIC TRINKET BOX        24   1.25        30.00
# ...                                     ...       ...    ...          ...
# 525456                 FELTCRAFT DOLL ROSIE         2   2.95         5.90
# 525457         FELTCRAFT PRINCESS LOLA DOLL         1   3.75         3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL         1   3.75         3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG         2   3.75         7.50
# 525460               JUMBO STORAGE BAG SUKI         2   1.95         3.90
#
#         Recency
# 0      374 days
# 1      374 days
# 2      374 days
# 3      374 days
# 4      374 days
# ...         ...
# 525456   1 days
# 525457   1 days
# 525458   1 days
# 525459   1 days
# 525460   1 days
#
# [504731 rows x 10 columns]

# %%
df_frequency = df[['Customer ID', 'InvoiceDate']].groupby(['Customer ID'], as_index=False).count().rename(columns={'InvoiceDate':'Shopping Frequency'})
df_frequency
# Out:
#       Customer ID  Shopping Frequency
# 0           12346                  33
# 1           12347                  71
# 2           12348                  20
# 3           12349                 103
# 4           12351                  21
# ...           ...                 ...
# 4309        18283                 222
# 4310        18284                  28
# 4311        18285                  12
# 4312        18286                  67
# 4313        18287                  85
#
# [4314 rows x 2 columns]

# %%
df_monetery = df[['Customer ID', 'Total Price']].groupby(['Customer ID'], as_index=False).sum().rename(columns={'Total Price':'Total Spending'})
df_monetery
# Out:
#       Customer ID  Total Spending
# 0           12346          372.86
# 1           12347         1323.32
# 2           12348          222.16
# 3           12349         2696.67
# 4           12351          300.93
# ...           ...             ...
# 4309        18283          639.92
# 4310        18284          461.68
# 4311        18285          427.00
# 4312        18286         1296.43
# 4313        18287         2345.71
#
# [4314 rows x 2 columns]

# %%
df_recency = df[['Customer ID', 'Recency']].groupby(['Customer ID'], as_index=False).min()
df_recency
# Out:
#       Customer ID  Recency
# 0           12346 165 days
# 1           12347   3 days
# 2           12348  74 days
# 3           12349  43 days
# 4           12351  11 days
# ...           ...      ...
# 4309        18283  18 days
# 4310        18284  67 days
# 4311        18285 296 days
# 4312        18286 112 days
# 4313        18287  18 days
#
# [4314 rows x 2 columns]

# %%
pd.concat([df_recency, df_frequency.drop('Customer ID', axis=1), df_monetery.drop('Customer ID', axis=1)], join='inner', axis=1)
# Out:
#       Customer ID  Recency  Shopping Frequency  Total Spending
# 0           12346 165 days                  33          372.86
# 1           12347   3 days                  71         1323.32
# 2           12348  74 days                  20          222.16
# 3           12349  43 days                 103         2696.67
# 4           12351  11 days                  21          300.93
# ...           ...      ...                 ...             ...
# 4309        18283  18 days                 222          639.92
# 4310        18284  67 days                  28          461.68
# 4311        18285 296 days                  12          427.00
# 4312        18286 112 days                  67         1296.43
# 4313        18287  18 days                  85         2345.71
#
# [4314 rows x 4 columns]

# %%
df_recency.merge(df_frequency.merge(df_monetery, on='Customer ID'), on='Customer ID')
# Out:
#       Customer ID  Recency  Shopping Frequency  Total Spending
# 0           12346 165 days                  33          372.86
# 1           12347   3 days                  71         1323.32
# 2           12348  74 days                  20          222.16
# 3           12349  43 days                 103         2696.67
# 4           12351  11 days                  21          300.93
# ...           ...      ...                 ...             ...
# 4309        18283  18 days                 222          639.92
# 4310        18284  67 days                  28          461.68
# 4311        18285 296 days                  12          427.00
# 4312        18286 112 days                  67         1296.43
# 4313        18287  18 days                  85         2345.71
#
# [4314 rows x 4 columns]

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Data Preprocessing</p>**

# %%
from sklearn import preprocessing

df6['recency_log'] = df6['Recency'].apply(math.log)
df6['frequency_log'] = df6['Frequency'].apply(math.log)
df6['amount_log'] = df6['Amount'].apply(math.log)
feature_vector = ['amount_log', 'recency_log','frequency_log']

X = df6[feature_vector]
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %%
plt.figure(figsize=(12,12))
sns.distplot(df6['amount_log'])

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax  = fig.add_subplot(111, projection='3d')
xs  = df6.recency_log
ys  = df6.frequency_log
zs  = df6.amount_log

ax.scatter(xs, ys, zs, s=5)
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetary')

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Train & Evaluate The Model</p>**

# %%
X = X_scaled

cluster_centers = dict()

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    fig, (ax1, ax2) = plt.subplots(1, 2)
    #ax2 = plt.subplot(111, projection='3d')
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    silhouette_avg = silhouette_score(X, cluster_labels)
    cluster_centers.update({n_clusters :{
                                        'cluster_center':clusterer.cluster_centers_,
                                        'silhouette_score':silhouette_avg,
                                        'labels':cluster_labels}
                           })

    sample_silhouette_values = silhouette_samples(X, cluster_labels)
    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.get_cmap("Spectral")(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax1.set_yticks([])
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    colors = cm.get_cmap("Spectral")(cluster_labels.astype(float) / n_clusters)
    feature1 = 0
    feature2 = 2
    ax2.scatter(X[:, feature1], X[:, feature2], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')
    
    centers = clusterer.cluster_centers_
    ax2.scatter(centers[:, feature1], centers[:, feature2], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')
    for i, c in enumerate(centers):
        ax2.scatter(c[feature1], c[feature2], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')
    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature i.e. monetary value")
    ax2.set_ylabel("Feature space for the 2nd feature i.e. frequency")
    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    plt.show()

# %%
wcss = [] #Elbow method can be als used to determine the best number of cluster for our data

for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
wcss

# %%
plt.figure()
plt.plot(range(1,10), wcss)
plt.xlabel('Number of Cluster')
plt.ylabel('WCSS')

# %%
for i in range_n_clusters:
    print("for {} number of clusters".format(i))
    cent_transformed = scaler.inverse_transform(cluster_centers[i]['cluster_center'])
    print(pd.DataFrame(np.exp(cent_transformed),columns=feature_vector))
    print("Silhouette score for cluster {} is {}". format(i, cluster_centers[i]['silhouette_score']))
    print()

# %% [markdown]
# ## Deciding The Number of Cluster
#
# ##### From the Silhouette score, it can be seen that the number of cluster that has high score is 2 and 3. In parallel, from the elbow method, it can be seen that 2 and 3 are the best fit number of cluster. Thus, 2 and 3 number of clusters are going to be used. But, it is more effective to use 3 number of clusters, 2 clusters more likely classification task.

# %%
labels = cluster_centers[2]['labels']   
df6['num_cluster2_labels'] = labels
labels = cluster_centers[3]['labels']
df6['num_cluster3_labels'] = labels

# %%
df6

# %% [markdown]
# ### **<p style="color:  #4ceae5 ">Save The Model</p>**
